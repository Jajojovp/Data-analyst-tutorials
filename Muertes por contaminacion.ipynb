# %% [markdown]
# <a href="https://colab.research.google.com/github/jajovp/Data-analyst-tutorials/blob/main/Muertes%20por%20contaminacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_csv("/content/drive/MyDrive/Muertes por contaminacion - Hoja 1.csv")
# To display the top 5 rows 
df.head(10)
# Out:
#    index  cartodb_id  the_geom        Country Name  the_geom_webmercator  \
# 0      0           1       NaN        Saudi Arabia                   NaN
# 1      1           2       NaN             Romania                   NaN
# 2      2           3       NaN               Spain                   NaN
# 3      3           4       NaN            Slovenia                   NaN
# 4      4           5       NaN         South Sudan                   NaN
# 5      5           6       NaN        Sierra Leone                   NaN
# 6      6           7       NaN        South Africa                   NaN
# 7      7           8       NaN  Republic of Serbia                   NaN
# 8      8           9       NaN            Slovakia                   NaN
# 9      9          10       NaN     Solomon Islands                   NaN
#
#   Country Code          country  cri_rank  cri_score  \
# 0          SAU     Saudi Arabia        79        725
# 1          ROU          Romania        61        615
# 2          ESP            Spain        69       6633
# 3          SVN         Slovenia       135       1245
# 4          SSD      South Sudan       133      11733
# 5          SLE     Sierra Leone       102        885
# 6          ZAF     South Africa        33       4567
# 7          SRB           Serbia        83        755
# 8          SVK  Slovak Republic       123      10533
# 9          SLB  Solomon Islands        89       7683
#
#    fatalities_per_100k_rank  fatalities_per_100k_total  fatalities_rank  \
# 0                        18                         45               18
# 1                       112                          1              102
# 2                        74                          5               47
# 3                       114                          0              114
# 4                       114                          0              114
# 5                        42                         16               68
# 6                        84                          3               51
# 7                       114                          0              114
# 8                        97                          2              102
# 9                        39                         17              102
#
#    fatalities_total  losses_per_gdp__rank  losses_per_gdp__total  \
# 0               140                   131                    1.0
# 1                 1                    16                 6746.0
# 2                22                    86                  394.0
# 3                 0                   135                    NaN
# 4                 0                   120                   21.0
# 5                10                   124                   11.0
# 6                19                    24                 4722.0
# 7                 0                    33                 2794.0
# 8                 1                   115                   46.0
# 9                 1                    80                  445.0
#
#    losses_usdm_ppp_rank  losses_usdm_ppp_total
# 0                   119                   1229
# 1                    11                2797884
# 2                    31                  63707
# 3                   135                      0
# 4                   122                    508
# 5                   131                    114
# 6                     7                3427958
# 7                    45                 272927
# 8                   106                   7468
# 9                   121                    511

# %%
df.tail(5)
# Out:
#      index  cartodb_id  the_geom         Country Name  the_geom_webmercator  \
# 177    177         178       NaN           Seychelles                   NaN
# 178    178         179       NaN               Gambia                   NaN
# 179    179         180       NaN                 Togo                   NaN
# 180    180         181       NaN  Trinidad and Tobago                   NaN
# 181    181         182       NaN                Tonga                   NaN
#
#     Country Code              country  cri_rank  cri_score  \
# 177          SYC           Seychelles       135       1245
# 178          GMB               Gambia       135       1245
# 179          TGO                 Togo       131      11433
# 180          TTO  Trinidad and Tobago       135       1245
# 181          TON                Tonga       135       1245
#
#      fatalities_per_100k_rank  fatalities_per_100k_total  fatalities_rank  \
# 177                       114                          0              114
# 178                       114                          0              114
# 179                       104                          1              102
# 180                       114                          0              114
# 181                       114                          0              114
#
#      fatalities_total  losses_per_gdp__rank  losses_per_gdp__total  \
# 177                 0                   135                    NaN
# 178                 0                   135                    NaN
# 179                 1                   123                   12.0
# 180                 0                   135                    NaN
# 181                 0                   135                    NaN
#
#      losses_usdm_ppp_rank  losses_usdm_ppp_total
# 177                   135                      0
# 178                   135                      0
# 179                   130                     13
# 180                   135                      0
# 181                   135                      0

# %%
df.dtypes
# Out:
# index                          int64
# cartodb_id                     int64
# the_geom                     float64
# Country Name                  object
# the_geom_webmercator         float64
# Country Code                  object
# country                       object
# cri_rank                       int64
# cri_score                      int64
# fatalities_per_100k_rank       int64
# fatalities_per_100k_total      int64
# fatalities_rank                int64
# fatalities_total               int64
# losses_per_gdp__rank           int64
# losses_per_gdp__total        float64
# losses_usdm_ppp_rank           int64
# losses_usdm_ppp_total          int64
# dtype: object

# %%
df.columns
# Out:
# Index(['index', 'cartodb_id', 'the_geom', 'Country Name',
#        'the_geom_webmercator', 'Country Code', 'country', 'cri_rank',
#        'cri_score', 'fatalities_per_100k_rank', 'fatalities_per_100k_total',
#        'fatalities_rank', 'fatalities_total', 'losses_per_gdp__rank',
#        'losses_per_gdp__total', 'losses_usdm_ppp_rank',
#        'losses_usdm_ppp_total'],
#       dtype='object')

# %% [markdown]
# Calculamos y vemos los paises el puntaje (valor numérico) en términos de índice de riesgo de desastres.

# %%
# Ordenar el DataFrame por la columna "cri_score"
df_sorted = df.sort_values("cri_score")

# %%
# Seleccionar los primeros 10 registros del DataFrame ordenado
df_top10 = df_sorted.head(10)

# %%
# Graficar los 10 primeros registros en un gráfico de barras
plt.bar(df_top10["Country Code"], df_top10["cri_score"])
plt.xlabel("País")
plt.ylabel("Índice de riesgo de desastres")
plt.show()

# %%
# Ordena el DataFrame por la columna "fatalities_total" en orden ascendente
df_sorted = df.sort_values('fatalities_total')

# %%
# Selecciona los primeros 10 países de la tabla ordenada
top_10 = df_sorted.tail(10)

# %%
# Grafica los 10 países seleccionados en un gráfico vertical
plt.barh(top_10['country'], top_10['fatalities_total'])
plt.xlabel('Número total de muertes')
plt.ylabel('País')
plt.title('Los 10 países con más muertes por desastres naturales')
plt.show()

# %%
# Crear DataFrame con los datos
data = {'Country Name': ['Mexico', 'China', 'Indonesia', 'India', 'Philippines',
                         'Iran, Islamic Rep.', 'Pakistan', 'Bangladesh', 'Nigeria', 'Vietnam'],
        'fatalities_total': [93877, 88794, 83969, 57832, 36877,
                             34505, 33371, 29108, 28011, 24426],
        'losses_per_gdp__total': [0.33, 0.27, 0.48, 0.05, 3.57,
                                  0.12, 0.46, 0.15, 0.05, 1.06]}
df = pd.DataFrame(data)

# %%
# Ordenar DataFrame por el valor de la columna 'fatalities_total'
df_sorted = df.sort_values('fatalities_total', ascending=False)

# %%
# Seleccionar los 10 primeros países
df_top10 = df_sorted.head(10)

# %%
# Crear gráfico vertical
colors = plt.cm.get_cmap('Reds')(df_top10['losses_per_gdp__total'])
plt.bar(df_top10['Country Name'], df_top10['fatalities_total'], color=colors, alpha=0.8)

# Agregar título y etiquetas de los ejes
plt.title('Top 10 países con más muertes por desastres naturales')
plt.xlabel('Países')
plt.ylabel('Número total de muertes')
# Out:
# Text(0, 0.5, 'Número total de muertes')
